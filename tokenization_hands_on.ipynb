# %% [markdown]
# <a href="https://colab.research.google.com/github/venus751/Hello--world/blob/main/tokenization_hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
#Installing HuggingFace library
# !pip install transformers -q

# %%
from transformers import AutoTokenizer

# %%
#loading a pretrained Tokenizer
tokenizer =AutoTokenizer.from_pretrained('google-bert/bert-base-uncased')
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
#convert text to tokens

text = 'i love Machine Learning !'

tokens = tokenizer.tokenize(text)

print("Tokens:", tokens)
# Out:
# Tokens: ['i', 'love', 'machine', 'learning', '!']

# %% [markdown]
# Each Tokens -> unique Token IDs

# %%
#tokens to tokens IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Token_IDs:", token_ids)
# Out:
# Token_IDs: [1045, 2293, 3698, 4083, 999]

# %% [markdown]
# Direct Method

# %%
text = "I love Machine Learning"

encoded = tokenizer(text)
print(encoded)
# Out:
# {'input_ids': [101, 1045, 2293, 3698, 4083, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1]}

# %%
input_text

tokenizer

token_id

 model

 output_token_ids

 tokenizer(decoding)

 output_text

# %%
#decode back (after a model generate output as token ids)

decoded = tokenizer.decode([101, 1045, 2293, 3698, 4083, 102])

print("Decoded_Text:", decoded)
# Out:
# Decoded_Text: [CLS] i love machine learning [SEP]

# %%
text = 'flabbergasted'

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['fl', '##ab', '##berg', '##ast', '##ed']

# %%
encode = tokenizer(text)
print(encode)
# Out:
# {'input_ids': [101, 13109, 7875, 4059, 14083, 2098, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}
